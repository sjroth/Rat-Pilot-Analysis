# %%
import os

# %%
os.chdir('../../../Rat-Pilot/data/tag_directories/')

# %% [markdown]
# Create a bigwig hub

# %%
# %%time
# %%bash
makeMultiWigHub.pl rat-pilot rn6 -url http://homer.ucsd.edu/sjroth/Rat-Pilot -webdir /homer_data/www/html/sjroth/Rat-Pilot -d *
# Out:
# Colors that will be used (change with -color or -gradient options):
# 	Index	Color	Neg. color	Tag Directory
# 	1	255,150,150	(255,180,180)	H3K27ac1-IL
# 	2	150,150,255	(180,180,255)	H3K27ac2-PL
# 	3	150,255,150	(180,255,180)	H3K27ac4-ST
# 	4	255,200,150	(255,210,180)	H3K27ac5-AC
# 	5	150,255,220	(180,255,240)	H3K27ac6-AS
# 	6	200,150,255	(210,180,255)	H3K27ac7-VTA
# 	7	200,200,150	(210,210,170)	Input1-IL
# 	8	150,200,200	(170,210,210)	Input2-PL
# 	9	200,150,200	(210,170,210)	Input4-ST
# 	10	59,5,171	(244,134,234)	Input5-AC
# 	11	228,251,92	(82,113,54)	Input6-AS
# 	12	215,9,1	(206,47,115)	Input7-VTA
# 	13	217,241,114	(216,190,192)	test.txt
#
#
# 	Once finished, you will want to upload the following hub URL:
# 		http://homer.ucsd.edu/sjroth/Rat-Pilot/rat-pilot/hub.txt
#
# 	If loading to the Wash U Epigenome Browser, use:
# 		http://homer.ucsd.edu/sjroth/Rat-Pilot/rat-pilot/washU.hub.txt
#
#
# 	Visualization fragment length = 177
# 	Output file: H3K27ac1-IL/H3K27ac1-IL.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac1-IL/H3K27ac1-IL.ucsc.bigWig
#
# 	Visualization fragment length = 175
# 	Output file: H3K27ac2-PL/H3K27ac2-PL.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac2-PL/H3K27ac2-PL.ucsc.bigWig
#
# 	Visualization fragment length = 165
# 	Output file: H3K27ac4-ST/H3K27ac4-ST.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac4-ST/H3K27ac4-ST.ucsc.bigWig
#
# 	Visualization fragment length = 173
# 	Output file: H3K27ac5-AC/H3K27ac5-AC.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac5-AC/H3K27ac5-AC.ucsc.bigWig
#
# 	Visualization fragment length = 163
# 	Output file: H3K27ac6-AS/H3K27ac6-AS.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac6-AS/H3K27ac6-AS.ucsc.bigWig
#
# 	Visualization fragment length = 169
# 	Output file: H3K27ac7-VTA/H3K27ac7-VTA.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph H3K27ac7-VTA/H3K27ac7-VTA.ucsc.bigWig
#
# 	Visualization fragment length = 141
# 	Output file: Input1-IL/Input1-IL.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input1-IL/Input1-IL.ucsc.bigWig
#
# 	Visualization fragment length = 167
# 	Output file: Input2-PL/Input2-PL.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input2-PL/Input2-PL.ucsc.bigWig
#
# 	Visualization fragment length = 147
# 	Output file: Input4-ST/Input4-ST.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input4-ST/Input4-ST.ucsc.bigWig
#
# 	Visualization fragment length = 152
# 	Output file: Input5-AC/Input5-AC.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input5-AC/Input5-AC.ucsc.bigWig
#
# 	Visualization fragment length = 150
# 	Output file: Input6-AS/Input6-AS.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input6-AS/Input6-AS.ucsc.bigWig
#
# 	Visualization fragment length = 161
# 	Output file: Input7-VTA/Input7-VTA.ucsc.bigWig
# 	No need to remove tags to get desired file size
# 	Generating bedGraph for chr1
# 	Generating bedGraph for chr10
# 	Generating bedGraph for chr11
# 	Generating bedGraph for chr12
# 	Generating bedGraph for chr13
# 	Generating bedGraph for chr14
# 	Generating bedGraph for chr15
# 	Generating bedGraph for chr16
# 	Generating bedGraph for chr17
# 	Generating bedGraph for chr18
# 	Generating bedGraph for chr19
# 	Generating bedGraph for chr2
# 	Generating bedGraph for chr20
# 	Generating bedGraph for chr3
# 	Generating bedGraph for chr4
# 	Generating bedGraph for chr5
# 	Generating bedGraph for chr6
# 	Generating bedGraph for chr7
# 	Generating bedGraph for chr8
# 	Generating bedGraph for chr9
# 	Generating bedGraph for chrM
# 	Generating bedGraph for chrX
# 	Generating bedGraph for chrY
# 	Creating bigWig from bedGraph Input7-VTA/Input7-VTA.ucsc.bigWig
# print() on closed filehandle HUBLIST at /gpfs/data01/bennerlab/home/sjroth/software/homer/bin/makeMultiWigHub.pl line 382, <IN> line 155.
# print() on closed filehandle HUBLIST at /gpfs/data01/bennerlab/home/sjroth/software/homer/bin/makeMultiWigHub.pl line 384, <IN> line 155.
# !!! Could not open tag information file: test.txt/tagInfo.txt
# Probably not a valid tag directory.  Quitting...
# mv: cannot stat ‘test.txt/test.txt.ucsc.bigWig’: Not a directory
#
# 	All finished: you will want to upload the following hub URL:
# 		http://homer.ucsd.edu/sjroth/Rat-Pilot/rat-pilot/hub.txt
#
# 	If loading to the Wash U Epigenome Browser, use:
# 		http://homer.ucsd.edu/sjroth/Rat-Pilot/rat-pilot/washU.hub.txt
#
#
# 	To edit track settings, edit files in:
# 		/homer_data/www/html/sjroth/Rat-Pilot/rat-pilot
# CPU times: user 47.2 ms, sys: 20.6 ms, total: 67.8 ms
# Wall time: 19min 14s

# %% [markdown]
# Vary peak-finding in order to discover optimal parameters. Using striatum as sample.

# %%
import sarge
from multiprocessing import Pool

# %%
'''
Define a function that can call peaks by varying parameters.
'''
def call_peaks(args):
    
    tag_dir,input_dir,fold_enrichment,poisson,out_name = args
    
    cmd = f'findPeaks {tag_dir} -style histone -i {input_dir} -F {fold_enrichment} -poisson {poisson} -o {out_name}'
    sarge.run(cmd)

# %%
tag_dir = 'H3K27ac4-ST/'
input_dir = 'Input4-ST/'

# %% [markdown]
# Vary fold enrichment over background

# %%
#Set other parameters.
poisson = '1e-3'

# %%
cmds = []
for i in range(5,9):
    cmds.append([tag_dir,input_dir,str(i),poisson,f'peaks-FoldEnrich-{i}.txt'])
cmds
# Out:
# [['H3K27ac4-ST/', 'Input4-ST/', '5', '1e-3', 'peaks-FoldEnrich-5.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '6', '1e-3', 'peaks-FoldEnrich-6.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '7', '1e-3', 'peaks-FoldEnrich-7.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '8', '1e-3', 'peaks-FoldEnrich-8.txt']]

# %% [markdown]
# Vary poisson p-value cutoff

# %%
#Set other parameters.
fold_enrichment = '4'

# %%
for i in range(-8,-4):
    cmds.append([tag_dir,input_dir,fold_enrichment,f'1e{i}',f'peaks-Poisson-1e{i}.txt'])
cmds
# Out:
# [['H3K27ac4-ST/', 'Input4-ST/', '5', '1e-3', 'peaks-FoldEnrich-5.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '6', '1e-3', 'peaks-FoldEnrich-6.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '7', '1e-3', 'peaks-FoldEnrich-7.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '8', '1e-3', 'peaks-FoldEnrich-8.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '4', '1e-8', 'peaks-Poisson-1e-8.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '4', '1e-7', 'peaks-Poisson-1e-7.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '4', '1e-6', 'peaks-Poisson-1e-6.txt'],
#  ['H3K27ac4-ST/', 'Input4-ST/', '4', '1e-5', 'peaks-Poisson-1e-5.txt']]

# %% [markdown]
# Run peak finding

# %%
pool = Pool(processes=len(cmds))
pool.map(call_peaks,cmds)
pool.close()

# %% [markdown]
# Get distal peaks only

# %%
'''
Define a function that can isolate the distal peaks.
'''
def get_distal_peaks(peakfile):
    
    cmd = f'getDistalPeaks.pl {peakfile} rn6 > {peakfile[:-3]}-distal.txt'
    sarge.run(cmd)

# %%
peak_files = [x[-1] for x in cmds]
peak_files
# Out:
# ['peaks-FoldEnrich-5.txt',
#  'peaks-FoldEnrich-6.txt',
#  'peaks-FoldEnrich-7.txt',
#  'peaks-FoldEnrich-8.txt',
#  'peaks-Poisson-1e-8.txt',
#  'peaks-Poisson-1e-7.txt',
#  'peaks-Poisson-1e-6.txt',
#  'peaks-Poisson-1e-5.txt']

# %%
pool = Pool(processes=len(peak_files))
pool.map(get_distal_peaks,peak_files)
pool.close()

# %% [markdown]
# Perform motif finding

# %%
# %%time
# %%bash
batchFindMotifsGenome.pl rn6 -size 500 -cpu 8 -p 10 \
-preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed -f *distal*
# Out:
# 	125345 finished
# findMotifsGenome.pl "peaks-FoldEnrich-5.-distal.txt" rn6 "Motifs-peaks-FoldEnrich-5.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-FoldEnrich-6.-distal.txt" rn6 "Motifs-peaks-FoldEnrich-6.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-FoldEnrich-7.-distal.txt" rn6 "Motifs-peaks-FoldEnrich-7.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-FoldEnrich-8.-distal.txt" rn6 "Motifs-peaks-FoldEnrich-8.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-Poisson-1e-5.-distal.txt" rn6 "Motifs-peaks-Poisson-1e-5.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-Poisson-1e-6.-distal.txt" rn6 "Motifs-peaks-Poisson-1e-6.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-Poisson-1e-7.-distal.txt" rn6 "Motifs-peaks-Poisson-1e-7.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
# findMotifsGenome.pl "peaks-Poisson-1e-8.-distal.txt" rn6 "Motifs-peaks-Poisson-1e-8.-distal.txt"  -size 500 -p 10 -preparsedDir /gpfs/data01/bennerlab/home/sjroth/software/homer/data/genomes/rn6/preparsed
#
# 	Position file = peaks-Poisson-1e-6.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-Poisson-1e-6.-distal.txt
#
# 	Position file = peaks-FoldEnrich-8.-distal.txt
# 	Genome = rn6
# 	Fragment size set to 500
# 	Output Directory = Motifs-peaks-FoldEnrich-8.-distal.txt
# 	Using 10 CPUs
# 	Fragment size set to 500
#
# 	Using 10 CPUs
# 	Position file = peaks-FoldEnrich-7.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-FoldEnrich-7.-distal.txt
# 	Fragment size set to 500
# 	Using 10 CPUs
#
# 	Position file = peaks-Poisson-1e-8.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-Poisson-1e-8.-distal.txt
# 	Fragment size set to 500
# 	Using 10 CPUs
#
#
# 	Position file = peaks-FoldEnrich-6.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-FoldEnrich-6.-distal.txt
# 	Position file = peaks-Poisson-1e-5.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-Poisson-1e-5.-distal.txt
# 	Fragment size set to 500
# 	Fragment size set to 500
# 	Using 10 CPUs
# 	Using 10 CPUs
#
# 	Position file = peaks-Poisson-1e-7.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-Poisson-1e-7.-distal.txt
# 	Fragment size set to 500
# 	Using 10 CPUs
#
# 	Position file = peaks-FoldEnrich-5.-distal.txt
# 	Genome = rn6
# 	Output Directory = Motifs-peaks-FoldEnrich-5.-distal.txt
# 	Fragment size set to 500
# 	Using 10 CPUs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Found mset for "rat", will check against vertebrates motifs
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 8076
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 11159
#
# 	Peak File Statistics:
# 		Total Peaks: 8076
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
#
# 	Peak File Statistics:
# 		Total Peaks: 11159
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 15546
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 21990
#
# 	Peak File Statistics:
# 		Total Peaks: 15546
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background files for 500 bp fragments found.
# 	Background files for 500 bp fragments found.
#
# 	Peak File Statistics:
# 		Total Peaks: 21990
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background files for 500 bp fragments found.
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 40808
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 45089
# 	Background files for 500 bp fragments found.
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 50337
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 0
# 		peakfile formatted lines: 56277
#
# 	Peak File Statistics:
# 		Total Peaks: 40808
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
#
# 	Peak File Statistics:
# 		Total Peaks: 45089
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
#
# 	Peak File Statistics:
# 		Total Peaks: 50337
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
#
# 	Peak File Statistics:
# 		Total Peaks: 56277
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background files for 500 bp fragments found.
# 	Background files for 500 bp fragments found.
# 	Background files for 500 bp fragments found.
# 	Background files for 500 bp fragments found.
#
#
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
#
# 	Extracting 1130 sequences from chr1
# 	Extracting 828 sequences from chr1
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 1573 sequences from chr1
#
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 2242 sequences from chr1
#
#
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 4167 sequences from chr1
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 4528 sequences from chr1
#
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 5071 sequences from chr1
#
# 	Extracting sequences from file: /gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa
# 	Looking for peak sequences in a single file (/gpfs/data01/cbenner/software/homer/.//data/genomes/rn6///genome.fa)
# 	Extracting 5710 sequences from chr1
# 	Extracting 976 sequences from chr10
# 	Extracting 697 sequences from chr10
# 	Extracting 2972 sequences from chr10
# 	Extracting 3264 sequences from chr10
# 	Extracting 1765 sequences from chr10
# 	Extracting 1298 sequences from chr10
# 	Extracting 279 sequences from chr11
# 	Extracting 217 sequences from chr11
# 	Extracting 1117 sequences from chr11
# 	Extracting 1244 sequences from chr11
# 	Extracting 548 sequences from chr11
# 	Extracting 367 sequences from chr11
# 	Extracting 3645 sequences from chr10
# 	Extracting 1414 sequences from chr12
# 	Extracting 447 sequences from chr12
# 	Extracting 335 sequences from chr12
# 	Extracting 1538 sequences from chr12
# 	Extracting 602 sequences from chr12
# 	Extracting 806 sequences from chr12
# 	Extracting 4027 sequences from chr10
# 	Extracting 341 sequences from chr13
# 	Extracting 1351 sequences from chr13
# 	Extracting 1507 sequences from chr13
# 	Extracting 230 sequences from chr13
# 	Extracting 683 sequences from chr13
# 	Extracting 480 sequences from chr13
# 	Extracting 1405 sequences from chr11
# 	Extracting 376 sequences from chr14
# 	Extracting 1420 sequences from chr14
# 	Extracting 256 sequences from chr14
# 	Extracting 1565 sequences from chr14
# 	Extracting 1548 sequences from chr11
# 	Extracting 528 sequences from chr14
# 	Extracting 747 sequences from chr14
# 	Extracting 1718 sequences from chr12
# 	Extracting 1898 sequences from chr12
# 	Extracting 354 sequences from chr15
# 	Extracting 1315 sequences from chr15
# 	Extracting 1699 sequences from chr13
# 	Extracting 1434 sequences from chr15
# 	Extracting 255 sequences from chr15
# 	Extracting 493 sequences from chr15
# 	Extracting 680 sequences from chr15
# 	Extracting 1924 sequences from chr13
# 	Extracting 284 sequences from chr16
# 	Extracting 1313 sequences from chr16
# 	Extracting 1177 sequences from chr16
# 	Extracting 188 sequences from chr16
# 	Extracting 407 sequences from chr16
# 	Extracting 603 sequences from chr16
# 	Extracting 1753 sequences from chr14
# 	Extracting 1965 sequences from chr14
# 	Extracting 338 sequences from chr17
# 	Extracting 1627 sequences from chr17
# 	Extracting 1437 sequences from chr17
# 	Extracting 227 sequences from chr17
# 	Extracting 488 sequences from chr17
# 	Extracting 714 sequences from chr17
# 	Extracting 1627 sequences from chr15
# 	Extracting 1822 sequences from chr15
# 	Extracting 402 sequences from chr18
# 	Extracting 289 sequences from chr18
# 	Extracting 1560 sequences from chr18
# 	Extracting 1431 sequences from chr18
# 	Extracting 540 sequences from chr18
# 	Extracting 779 sequences from chr18
# 	Extracting 376 sequences from chr19
# 	Extracting 1345 sequences from chr19
# 	Extracting 287 sequences from chr19
# 	Extracting 1509 sequences from chr19
# 	Extracting 1695 sequences from chr16
# 	Extracting 538 sequences from chr19
# 	Extracting 776 sequences from chr19
# 	Extracting 1490 sequences from chr16
# 	Extracting 648 sequences from chr2
# 	Extracting 486 sequences from chr2
# 	Extracting 2728 sequences from chr2
# 	Extracting 3041 sequences from chr2
# 	Extracting 916 sequences from chr2
# 	Extracting 1338 sequences from chr2
# 	Extracting 2038 sequences from chr17
# 	Extracting 1821 sequences from chr17
# 	Extracting 1917 sequences from chr18
# 	Extracting 1736 sequences from chr18
# 	Extracting 1886 sequences from chr19
# 	Extracting 310 sequences from chr20
# 	Extracting 232 sequences from chr20
# 	Extracting 1192 sequences from chr20
# 	Extracting 1098 sequences from chr20
# 	Extracting 445 sequences from chr20
# 	Extracting 610 sequences from chr20
# 	Extracting 3838 sequences from chr2
# 	Extracting 1666 sequences from chr19
# 	Extracting 857 sequences from chr3
# 	Extracting 3074 sequences from chr3
# 	Extracting 3401 sequences from chr3
# 	Extracting 615 sequences from chr3
# 	Extracting 1203 sequences from chr3
# 	Extracting 1682 sequences from chr3
# 	Extracting 3386 sequences from chr2
# 	Extracting 498 sequences from chr4
# 	Extracting 698 sequences from chr4
# 	Extracting 3001 sequences from chr4
# 	Extracting 2674 sequences from chr4
# 	Extracting 992 sequences from chr4
# 	Extracting 1432 sequences from chr4
# 	Extracting 1486 sequences from chr20
# 	Extracting 4202 sequences from chr3
# 	Extracting 536 sequences from chr5
# 	Extracting 2927 sequences from chr5
# 	Extracting 723 sequences from chr5
# 	Extracting 2643 sequences from chr5
# 	Extracting 1325 sequences from chr20
# 	Extracting 1019 sequences from chr5
# 	Extracting 1478 sequences from chr5
# 	Extracting 3753 sequences from chr3
# 	Extracting 3795 sequences from chr4
# 	Extracting 739 sequences from chr6
# 	Extracting 535 sequences from chr6
# 	Extracting 2969 sequences from chr6
# 	Extracting 1504 sequences from chr6
# 	Extracting 1056 sequences from chr6
# 	Extracting 2675 sequences from chr6
# 	Extracting 3383 sequences from chr4
# 	Extracting 3661 sequences from chr5
# 	Extracting 3264 sequences from chr5
# 	Extracting 707 sequences from chr7
# 	Extracting 1310 sequences from chr7
# 	Extracting 951 sequences from chr7
# 	Extracting 2372 sequences from chr7
# 	Extracting 3683 sequences from chr6
# 	Extracting 518 sequences from chr7
# 	Extracting 2610 sequences from chr7
# 	Extracting 3312 sequences from chr6
# 	Extracting 1394 sequences from chr8
# 	Extracting 1003 sequences from chr8
# 	Extracting 711 sequences from chr8
# 	Extracting 2497 sequences from chr8
# 	Extracting 3192 sequences from chr7
# 	Extracting 492 sequences from chr8
# 	Extracting 2787 sequences from chr8
# 	Extracting 806 sequences from chr9
# 	Extracting 426 sequences from chr9
# 	Extracting 1597 sequences from chr9
# 	Extracting 2884 sequences from chr7
# 	Extracting 588 sequences from chr9
# 	Extracting 324 sequences from chr9
# 	Extracting 3467 sequences from chr8
# 	Extracting 1750 sequences from chr9
# 	Extracting 93 sequences from chrX
# 	Extracting 302 sequences from chrX
# 	Extracting 37 sequences from chrX
# 	Extracting 59 sequences from chrX
# 	Extracting 3114 sequences from chr8
# 	Extracting 31 sequences from chrX
# 	Extracting 2165 sequences from chr9
# 	Extracting 320 sequences from chrX
# 	Extracting 2 sequences from chrY
# 	Extracting 1945 sequences from chr9
# 	Extracting 356 sequences from chrX
# 	Extracting 2 sequences from chrY
# 	Extracting 338 sequences from chrX
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 	Extracting 2 sequences from chrY
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 		8076 total
# 		11159 total
#
#
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
#
# 	Not removing redundant sequences
# 	Extracting 2 sequences from chrY
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.35	3	5
# 	0.4	4	73
# 	0.45	5	461
# 	0.5	6	1689
# 	0.6	7	4121
# 	0.7	8	1175
# 	0.8	9	535
# 	10	10	17
#
# 	Total sequences set to 50000
#
# 	Choosing background that matches in CpG/GC content...
# 	Freq	Bin	Count
# 	0.35	3	10
# 	0.4	4	131
# 	0.45	5	851
# 	0.5	6	2635
# 	0.6	7	5639
# 	0.7	8	1317
# 	0.8	9	553
# 	10	10	23
#
# 	Total sequences set to 50000
#
# 	Choosing background that matches in CpG/GC content...
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 		15546 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
#
# 	Not removing redundant sequences
# 	Freq	Bin	Count
# 	0.3	2	1
# 	0.35	3	21
# 	0.4	4	243
# 	0.45	5	1502
# 	0.5	6	4073
# 	0.6	7	7650
# 	0.7	8	1447
# 	0.8	9	586
# 	10	10	23
#
# 	Total sequences set to 50000
#
# 	Choosing background that matches in CpG/GC content...
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 		21990 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
#
# 	Not removing redundant sequences
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 	Freq	Bin	Count
# 	0.3	2	1
# 	0.35	3	47
# 	0.4	4	495
# 	0.45	5	2614
# 	0.5	6	6344
# 	0.6	7	10289
# 	0.7	8	1580
# 	0.8	9	597
# 	10	10	23
#
# 	Total sequences set to 50000
#
# 	Choosing background that matches in CpG/GC content...
#
# 	Not removing redundant sequences
# 		40808 total
#
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
#
# 	Not removing redundant sequences
# 		45089 total
#
#
#
# 	Sequences processed:
# 		Auto detected maximum sequence length of 501 bp
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.3	2	11
# 	0.35	3	281
# 	0.4	4	2090
# 	0.45	5	7498
# 	0.5	6	13527
# 	0.6	7	15444
# 	0.7	8	1503
# 	0.8	9	439
# 	10	10	15
#
# 	Total sequences set to 81616
#
# 	Choosing background that matches in CpG/GC content...
# 	Freq	Bin	Count
# 	0.25	1	1
# 	0.3	2	11
# 	0.35	3	307
# 	0.4	4	2367
# 	0.45	5	8396
# 	0.5	6	15022
# 	0.6	7	16873
# 	0.7	8	1623
# 	0.8	9	472
# 	10	10	17
#
# 	Total sequences set to 90178
#
# 	Choosing background that matches in CpG/GC content...
# 		56277 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 		50337 total
#
# 	Frequency Bins: 0.2 0.25 0.3 0.35 0.4 0.45 0.5 0.6 0.7 0.8
# 	Freq	Bin	Count
# 	0.25	1	1
# 	0.3	2	18
# 	0.35	3	400
# 	0.4	4	3085
# 	0.45	5	10803
# 	0.5	6	18984
# 	0.6	7	20565
# 	0.7	8	1879
# 	0.8	9	522
# 	10	10	20
#
# 	Total sequences set to 112554
#
# 	Choosing background that matches in CpG/GC content...
# 	Freq	Bin	Count
# 	0.25	1	1
# 	0.3	2	12
# 	0.35	3	352
# 	0.4	4	2679
# 	0.45	5	9518
# 	0.5	6	16876
# 	0.6	7	18621
# 	0.7	8	1762
# 	0.8	9	499
# 	10	10	17
#
# 	Total sequences set to 100674
#
# 	Choosing background that matches in CpG/GC content...
# 	Bin	# Targets	# Background	Background Weight
# 	3	10	35	0.995
# 	4	131	456	1.000
# 	5	851	2962	1.000
# 	Bin	# Targets	# Background	Background Weight
# 	6	2635	9172	1.000
# 	2	1	2	1.108
# 	3	21	47	0.990
# 	4	243	539	0.999
# 	5	1502	3329	1.000
# 	6	4073	9027	1.000
# 	7	5639	19628	1.000
# 	8	1317	4584	1.000
# 	9	553	1925	1.000
# 	10	23	80	1.001
# 	7	7650	16954	1.000
# 	8	1447	3207	1.000
# 	9	586	1299	1.000
# 	10	23	51	1.000
# 	Assembling sequence file...
# 	Bin	# Targets	# Background	Background Weight
# 	Assembling sequence file...
# 	2	1	1	1.274
# 	3	47	60	0.998
# 	4	495	631	0.999
# 	5	2614	3330	1.000
# 	6	6344	8081	1.000
# 	7	10289	13106	1.000
# 	8	1580	2013	1.000
# 	9	597	760	1.001
# 	10	23	29	1.010
# 	Assembling sequence file...
# 	Bin	# Targets	# Background	Background Weight
# 	2	11	11	1.000
# 	3	281	281	1.000
# 	4	2090	2090	1.000
# 	5	7498	7498	1.000
# 	Bin	# Targets	# Background	Background Weight
# 	6	13527	13527	1.000
# 	1	1	1	1.000
# 	2	11	11	1.000
# 	3	307	307	1.000
# 	4	2367	2367	1.000
# 	5	8396	8396	1.000
# 	7	15444	15444	1.000
# 	8	1503	1503	1.000
# 	9	439	439	1.000
# 	10	15	15	1.000
# 	Bin	# Targets	# Background	Background Weight
# 	3	5	26	0.998
# 	4	73	379	1.000
# 	5	461	2393	1.000
# 	6	1689	8768	1.000
# 	6	15022	15022	1.000
# 	Assembling sequence file...
# 	7	4121	21393	1.000
# 	8	1175	6100	1.000
# 	9	535	2777	1.000
# 	10	17	88	1.003
# 	7	16873	16873	1.000
# 	8	1623	1623	1.000
# 	9	472	472	1.000
# 	10	17	17	1.000
# 	Assembling sequence file...
# 	Assembling sequence file...
# 	Bin	# Targets	# Background	Background Weight
# 	1	1	1	1.000
# 	2	18	18	1.000
# 	3	400	400	1.000
# 	4	3085	3085	1.000
# 	5	10803	10803	1.000
# 	6	18984	18984	1.000
# 	Bin	# Targets	# Background	Background Weight
# 	7	20565	20565	1.000
# 	1	1	1	1.000
# 	2	12	12	1.000
# 	8	1879	1879	1.000
# 	3	352	352	1.000
# 	9	522	522	1.000
# 	10	20	20	1.000
# 	4	2679	2679	1.000
# 	5	9518	9518	1.000
# 	Assembling sequence file...
# 	6	16876	16876	1.000
# 	7	18621	18621	1.000
# 	8	1762	1762	1.000
# 	9	499	499	1.000
# 	10	17	17	1.000
# 	Assembling sequence file...
# 	Normalizing lower order oligos using homer2
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
#
# 	Reading input files...
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	50001 total sequences read
# 	50001 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 	50001 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 	Autonormalization: 1-mers (4 total)
# 		A	23.10%	23.48%	0.984
# 		C	26.90%	26.52%	1.014
# 		G	26.90%	26.52%	1.014
# 		T	23.10%	23.48%	0.984
# 	Autonormalization: 2-mers (16 total)
# 		A	23.63%	23.95%	0.987
# 		C	26.37%	26.05%	1.012
# 		G	26.37%	26.05%	1.012
# 		T	23.63%	23.95%	0.987
# 		A	24.16%	24.44%	0.989
# 		C	25.84%	25.56%	1.011
# 		G	25.84%	25.56%	1.011
# 		T	24.16%	24.44%	0.989
# 	Autonormalization: 2-mers (16 total)
# 	Autonormalization: 2-mers (16 total)
# 		AA	5.75%	5.80%	0.992
# 		CA	7.53%	7.63%	0.987
# 		GA	6.34%	6.38%	0.995
# 		TA	3.48%	3.67%	0.947
# 		AC	5.19%	5.36%	0.968
# 		CC	8.34%	8.19%	1.018
# 		GC	7.03%	6.60%	1.065
# 		TC	6.34%	6.38%	0.995
# 		AG	8.15%	8.02%	1.016
# 		CG	2.88%	2.68%	1.074
# 		GG	8.34%	8.19%	1.018
# 		TG	7.53%	7.63%	0.987
# 		AT	4.01%	4.29%	0.934
# 		CT	8.15%	8.02%	1.016
# 		GT	5.19%	5.36%	0.968
# 		TT	5.75%	5.80%	0.992
# 		AA	5.99%	6.03%	0.994
# 		CA	7.61%	7.68%	0.991
# 		GA	6.36%	6.39%	0.995
# 		TA	3.66%	3.84%	0.953
# 		AC	5.25%	5.41%	0.971
# 		CC	8.03%	7.93%	1.013
# 		GC	6.73%	6.32%	1.064
# 		TC	6.36%	6.39%	0.995
# 		AG	8.16%	8.04%	1.015
# 		CG	2.56%	2.41%	1.063
# 		GG	8.03%	7.93%	1.013
# 		TG	7.61%	7.68%	0.991
# 		AT	4.22%	4.47%	0.945
# 		CT	8.16%	8.04%	1.015
# 		GT	5.25%	5.41%	0.971
# 		TT	5.99%	6.03%	0.994
# 	Autonormalization: 3-mers (64 total)
# 		AA	6.24%	6.27%	0.995
# 		CA	7.68%	7.73%	0.993
# 		GA	6.38%	6.40%	0.997
# 		TA	3.85%	4.02%	0.957
# 		AC	5.31%	5.47%	0.972
# 		CC	7.72%	7.65%	1.010
# 		GC	6.42%	6.05%	1.061
# 		TC	6.38%	6.40%	0.997
# 		AG	8.17%	8.03%	1.017
# 		CG	2.27%	2.15%	1.051
# 		GG	7.72%	7.65%	1.010
# 		TG	7.68%	7.73%	0.993
# 		AT	4.44%	4.66%	0.953
# 		CT	8.17%	8.03%	1.017
# 		GT	5.31%	5.47%	0.972
# 		TT	6.24%	6.27%	0.995
# 	Autonormalization: 3-mers (64 total)
# 	Autonormalization: 3-mers (64 total)
# 	Normalization weights can be found in file: Motifs-peaks-Poisson-1e-7.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Normalization weights can be found in file: Motifs-peaks-Poisson-1e-6.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Normalization weights can be found in file: Motifs-peaks-Poisson-1e-5.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	81616 total sequences read
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	Autonormalization: 1-mers (4 total)
# 	50000 total sequences read
# 	Autonormalization: 1-mers (4 total)
# 		A	25.37%	25.53%	0.994
# 		C	24.63%	24.47%	1.007
# 		G	24.63%	24.47%	1.007
# 		T	25.37%	25.53%	0.994
# 	Autonormalization: 2-mers (16 total)
# 	90178 total sequences read
# 		A	22.52%	22.97%	0.981
# 		C	27.48%	27.03%	1.016
# 		G	27.48%	27.03%	1.016
# 		T	22.52%	22.97%	0.981
# 	Autonormalization: 2-mers (16 total)
# 	Autonormalization: 1-mers (4 total)
# 		AA	5.50%	5.55%	0.991
# 		CA	7.42%	7.55%	0.983
# 		GA	6.31%	6.36%	0.993
# 		TA	3.28%	3.50%	0.939
# 		AC	5.12%	5.30%	0.965
# 		CC	8.68%	8.48%	1.024
# 		GC	7.37%	6.91%	1.067
# 		TC	6.31%	6.36%	0.993
# 		AG	8.10%	8.01%	1.011
# 		CG	3.27%	3.00%	1.090
# 		GG	8.68%	8.48%	1.024
# 		TG	7.42%	7.55%	0.983
# 		AT	3.80%	4.08%	0.930
# 		CT	8.10%	8.01%	1.011
# 		GT	5.12%	5.30%	0.965
# 		TT	5.50%	5.55%	0.991
# 		AA	6.84%	6.89%	0.994
# 		CA	7.78%	7.76%	1.003
# 		GA	6.39%	6.40%	0.999
# 		TA	4.35%	4.49%	0.970
# 		AC	5.45%	5.52%	0.986
# 		CC	7.04%	7.04%	0.999
# 		GC	5.76%	5.51%	1.045
# 		TC	6.39%	6.40%	0.999
# 		AG	8.08%	7.95%	1.016
# 		CG	1.73%	1.71%	1.010
# 		GG	7.04%	7.04%	0.999
# 		TG	7.78%	7.76%	1.003
# 		AT	5.00%	5.17%	0.967
# 		CT	8.08%	7.95%	1.016
# 		GT	5.45%	5.52%	0.986
# 		TT	6.84%	6.89%	0.994
# 	Autonormalization: 3-mers (64 total)
# 	Autonormalization: 3-mers (64 total)
# 		A	25.41%	25.56%	0.994
# 		C	24.59%	24.44%	1.006
# 		G	24.59%	24.44%	1.006
# 		T	25.41%	25.56%	0.994
# 	Autonormalization: 2-mers (16 total)
# 	Normalization weights can be found in file: Motifs-peaks-Poisson-1e-8.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Normalization weights can be found in file: Motifs-peaks-FoldEnrich-8.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 		AA	6.87%	6.90%	0.995
# 		CA	7.78%	7.77%	1.002
# 		GA	6.39%	6.40%	0.999
# 		TA	4.37%	4.50%	0.972
# 		AC	5.45%	5.53%	0.984
# 		CC	7.01%	7.03%	0.998
# 		GC	5.74%	5.48%	1.048
# 		TC	6.39%	6.40%	0.999
# 		AG	8.08%	7.95%	1.017
# 		CG	1.72%	1.70%	1.014
# 		GG	7.01%	7.03%	0.998
# 		TG	7.78%	7.77%	1.002
# 		AT	5.01%	5.18%	0.968
# 		CT	8.08%	7.95%	1.017
# 		GT	5.45%	5.53%	0.984
# 		TT	6.87%	6.90%	0.995
# 	Normalizing lower order oligos using homer2
#
# 	Reading input files...
# 	Autonormalization: 3-mers (64 total)
# 	112554 total sequences read
# 	100674 total sequences read
# ..	Autonormalization: 1-mers (4 total)
# 	Normalization weights can be found in file: Motifs-peaks-FoldEnrich-7.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 		Autonormalization: 1-mers (4 total)
# .		A	25.45%	25.60%	0.994
# 		C	24.55%	24.40%	1.006
# 		G	24.55%	24.40%	1.006
# 		T	25.45%	25.60%	0.994
# 		A	25.50%	25.65%	0.994
# 		C	24.50%	24.35%	1.006
# 		G	24.50%	24.35%	1.006
# 		T	25.50%	25.65%	0.994
# 	Autonormalization: 2-mers (16 total)
# 	Autonormalization: 2-mers (16 total)
# 		AA	6.89%	6.93%	0.994
# 		CA	7.78%	7.76%	1.003
# 		GA	6.39%	6.40%	0.999
# 		TA	4.39%	4.51%	0.973
# 		AC	5.45%	5.52%	0.987
# 		CC	6.99%	7.01%	0.996
# 		GC	5.72%	5.47%	1.046
# 		TC	6.39%	6.40%	0.999
# 		AG	8.08%	7.94%	1.017
# 		CG	1.70%	1.69%	1.010
# 		GG	6.99%	7.01%	0.996
# 		TG	7.78%	7.76%	1.003
# 		AT	5.03%	5.20%	0.968
# 		CT	8.08%	7.94%	1.017
# 		GT	5.45%	5.52%	0.987
# 		TT	6.89%	6.93%	0.994
# 		AA	6.92%	6.95%	0.995
# 		CA	7.78%	7.76%	1.003
# 		GA	6.40%	6.39%	1.001
# 		TA	4.41%	4.54%	0.970
# 		AC	5.45%	5.54%	0.985
# 		CC	6.95%	6.97%	0.998
# 		GC	5.69%	5.45%	1.045
# 		TC	6.40%	6.39%	1.001
# 		AG	8.07%	7.94%	1.017
# 		CG	1.68%	1.67%	1.006
# 		GG	6.95%	6.97%	0.998
# 		TG	7.78%	7.76%	1.003
# 		AT	5.06%	5.22%	0.968
# 		CT	8.07%	7.94%	1.017
# 		GT	5.45%	5.54%	0.985
# 		TT	6.92%	6.95%	0.995
# 	Autonormalization: 3-mers (64 total)
# 	Autonormalization: 3-mers (64 total)
# ..	Normalization weights can be found in file: Motifs-peaks-FoldEnrich-6.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	..	Normalization weights can be found in file: Motifs-peaks-FoldEnrich-5.-distal.txt/seq.autonorm.tsv
# 	Converging on autonormalization solution:
# 	.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	24.16%	24.16%	1.000
# 		C	25.84%	25.84%	1.000
# 		G	25.84%	25.84%	1.000
# 		T	24.16%	24.16%	1.000
# 	Autonormalization: 2-mers (16 total)
# 		AA	6.24%	6.21%	1.005
# 		CA	7.68%	7.68%	1.000
# 		GA	6.38%	6.40%	0.998
# 		TA	3.85%	3.87%	0.995
# 		AC	5.31%	5.35%	0.993
# 		CC	7.72%	7.75%	0.997
# 		GC	6.42%	6.34%	1.013
# 		TC	6.38%	6.40%	0.998
# 		AG	8.17%	8.14%	1.004
# 		CG	2.27%	2.27%	0.996
# 		GG	7.72%	7.75%	0.997
# 		TG	7.68%	7.68%	1.000
# 		AT	4.44%	4.46%	0.995
# 		CT	8.17%	8.14%	1.004
# 		GT	5.31%	5.35%	0.993
# 		TT	6.24%	6.21%	1.005
# 	Autonormalization: 3-mers (64 total)
# .	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# .	50001 total sequences read
# .	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	==......=...
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# .		A	23.63%	23.63%	1.000
# 		C	26.37%	26.37%	1.000
# 		G	26.37%	26.37%	1.000
# 		T	23.63%	23.63%	1.000
# 	Autonormalization: 2-mers (16 total)
# 		AA	5.99%	5.96%	1.005
# 		CA	7.61%	7.61%	1.000
# 		GA	6.36%	6.38%	0.997
# 		TA	3.66%	3.68%	0.995
# 		AC	5.25%	5.29%	0.993
# 		CC	8.03%	8.05%	0.998
# 		GC	6.73%	6.65%	1.012
# 		TC	6.36%	6.38%	0.997
# 		AG	8.16%	8.13%	1.004
# 		CG	2.56%	2.57%	0.996
# 		GG	8.03%	8.05%	0.998
# 		TG	7.61%	7.61%	1.000
# 		AT	4.22%	4.25%	0.994
# 		CT	8.16%	8.13%	1.004
# 		GT	5.25%	5.29%	0.993
# 		TT	5.99%	5.96%	1.005
# 	Autonormalization: 3-mers (64 total)
# .	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	50001 total sequences read
# 	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	===.......=.=.=...
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# =		A	23.10%	23.10%	1.000
# 		C	26.90%	26.90%	1.000
# 		G	26.90%	26.90%	1.000
# 		T	23.10%	23.10%	1.000
# .	Autonormalization: 2-mers (16 total)
# .
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	22.52%	22.53%	1.000
# 		C	27.48%	27.47%	1.000
# 		G	27.48%	27.47%	1.000
# 		T	22.52%	22.53%	1.000
# 		AA	5.75%	5.71%	1.006
# 		CA	7.53%	7.53%	1.000
# 		GA	6.34%	6.36%	0.997
# 		TA	3.48%	3.49%	0.996
# 		AC	5.19%	5.23%	0.993
# 		CC	8.34%	8.36%	0.998
# 		GC	7.03%	6.95%	1.011
# 		TC	6.34%	6.36%	0.997
# 		AG	8.15%	8.12%	1.004
# 		CG	2.88%	2.90%	0.996
# 		GG	8.34%	8.36%	0.998
# 		TG	7.53%	7.53%	1.000
# 		AT	4.01%	4.04%	0.991
# 		CT	8.15%	8.12%	1.004
# 		GT	5.19%	5.23%	0.993
# 		TT	5.75%	5.71%	1.006
# 	Autonormalization: 2-mers (16 total)
# 	Autonormalization: 3-mers (64 total)
# .		AA	5.50%	5.47%	1.007
# 		CA	7.42%	7.42%	1.000
# 		GA	6.31%	6.33%	0.997
# 		TA	3.28%	3.30%	0.994
# 		AC	5.12%	5.15%	0.993
# 		CC	8.68%	8.69%	0.999
# 		GC	7.37%	7.30%	1.010
# 		TC	6.31%	6.33%	0.997
# 		AG	8.10%	8.08%	1.004
# 		CG	3.27%	3.29%	0.996
# 		GG	8.68%	8.69%	0.999
# 		TG	7.42%	7.42%	1.000
# 		AT	3.80%	3.83%	0.992
# 		CT	8.10%	8.08%	1.004
# 		GT	5.12%	5.15%	0.993
# 		TT	5.50%	5.47%	1.007
# 	Autonormalization: 3-mers (64 total)
# 	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	50001 total sequences read
# 	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	==	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# 	50000 total sequences read
# 	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	====..===.=.=.=.=.==..====.=..==.=.==.=.===....===.====...====...=.===..==.==...===.=..====.=...=====.=.=..====..===..=.=.===...==.====..==..===.=.===..=.=.===..=.==.=.=.==.==...===.=..====.=.=.=..===.===..==..====..=..
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# =		A	25.37%	25.37%	1.000
# 		C	24.63%	24.63%	1.000
# 		G	24.63%	24.63%	1.000
# 		T	25.37%	25.37%	1.000
# 	Autonormalization: 2-mers (16 total)
# =		AA	6.84%	6.83%	1.003
# 		CA	7.78%	7.78%	1.001
# 		GA	6.39%	6.40%	0.998
# 		TA	4.35%	4.36%	0.997
# 		AC	5.45%	5.47%	0.995
# 		CC	7.04%	7.06%	0.997
# 		GC	5.76%	5.70%	1.011
# 		TC	6.39%	6.40%	0.998
# 		AG	8.08%	8.06%	1.003
# 		CG	1.73%	1.73%	0.997
# 		GG	7.04%	7.06%	0.997
# 		TG	7.78%	7.78%	1.001
# 		AT	5.00%	5.01%	0.997
# 		CT	8.08%	8.06%	1.003
# 		GT	5.45%	5.47%	0.995
# 		TT	6.84%	6.83%	1.003
# 	Autonormalization: 3-mers (64 total)
# =	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# =	81616 total sequences read
# 	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	===..=.=====.=.===.=.===.====..===.=.===.====.==.==.=.==.======..===.==.==..
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# 		A	25.41%	25.41%	1.000
# 		C	24.59%	24.59%	1.000
# 		G	24.59%	24.59%	1.000
# 		T	25.41%	25.41%	1.000
# 	Autonormalization: 2-mers (16 total)
# ==		AA	6.87%	6.85%	1.003
# 		CA	7.78%	7.77%	1.001
# 		GA	6.39%	6.41%	0.998
# 		TA	4.37%	4.38%	0.997
# 		AC	5.45%	5.48%	0.995
# 		CC	7.01%	7.04%	0.996
# 		GC	5.74%	5.67%	1.012
# 		TC	6.39%	6.41%	0.998
# 		AG	8.08%	8.05%	1.003
# 		CG	1.72%	1.73%	0.997
# 		GG	7.01%	7.04%	0.996
# 		TG	7.78%	7.77%	1.001
# 		AT	5.01%	5.03%	0.997
# 		CT	8.08%	8.05%	1.003
# 		GT	5.45%	5.48%	0.995
# 		TT	6.87%	6.85%	1.003
# 	Autonormalization: 3-mers (64 total)
# =	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
#
# 	Reading input files...
# ==	90178 total sequences read
# 	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	==.==.=====.==.======..======..=====.=======.===.=====.
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# .		A	25.45%	25.45%	1.000
# 		C	24.55%	24.55%	1.000
# 		G	24.55%	24.55%	1.000
# 		T	25.45%	25.45%	1.000
# 	Autonormalization: 2-mers (16 total)
# ==		AA	6.89%	6.87%	1.002
# 		CA	7.78%	7.78%	1.001
# 		GA	6.39%	6.40%	0.998
# 		TA	4.39%	4.40%	0.998
# 		AC	5.45%	5.48%	0.995
# 		CC	6.99%	7.02%	0.996
# 		GC	5.72%	5.65%	1.012
# 		TC	6.39%	6.40%	0.998
# 		AG	8.08%	8.05%	1.004
# 		CG	1.70%	1.71%	0.997
# 		GG	6.99%	7.02%	0.996
# 		TG	7.78%	7.78%	1.001
# 		AT	5.03%	5.05%	0.996
# 		CT	8.08%	8.05%	1.004
# 		GT	5.45%	5.48%	0.995
# 		TT	6.89%	6.87%	1.002
# 	Autonormalization: 3-mers (64 total)
# =	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
# ==
# 	Reading input files...
# ==	100674 total sequences read
# =	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	===.=========.============.=======.==========.=======.======.==========.============.=======.
# 	Final normalization:	Autonormalization: 1-mers (4 total)
# =		A	25.50%	25.50%	1.000
# 		C	24.50%	24.50%	1.000
# 		G	24.50%	24.50%	1.000
# 		T	25.50%	25.50%	1.000
# 	Autonormalization: 2-mers (16 total)
# ==		AA	6.92%	6.90%	1.003
# 		CA	7.78%	7.78%	1.001
# 		GA	6.40%	6.41%	0.998
# 		TA	4.41%	4.42%	0.997
# 		AC	5.45%	5.48%	0.995
# 		CC	6.95%	6.98%	0.996
# 		GC	5.69%	5.63%	1.012
# 		TC	6.40%	6.41%	0.998
# 		AG	8.07%	8.05%	1.003
# 		CG	1.68%	1.69%	0.997
# 		GG	6.95%	6.98%	0.996
# 		TG	7.78%	7.78%	1.001
# 		AT	5.06%	5.08%	0.997
# 		CT	8.07%	8.05%	1.003
# 		GT	5.45%	5.48%	0.995
# 		TT	6.92%	6.90%	1.003
# 	Autonormalization: 3-mers (64 total)
# ===	Finished preparing sequence/group files
#
# 	----------------------------------------------------------
# 	Known motif enrichment
# =
# 	Reading input files...
# ==	112554 total sequences read
# ==	428 motifs loaded
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 428 motif(s)
# 	|0%                                    50%                                  100%|
# 	===========================================
# 	Preparing HTML output with sequence logos...
# 		1 of 428 (1e-45) Tgif2(Homeobox)/mES-Tgif2-ChIP-Seq(GSE55404)/Homer
# 		2 of 428 (1e-36) NF1-halfsite(CTF)/LNCaP-NF1-ChIP-Seq(Unpublished)/Homer
# 		3 of 428 (1e-32) Mef2d(MADS)/Retina-Mef2d-ChIP-Seq(GSE61391)/Homer
# 		4 of 428 (1e-28) NFIL3(bZIP)/HepG2-NFIL3-ChIP-Seq(Encode)/Homer
# 		5 of 428 (1e-28) RFX(HTH)/K562-RFX3-ChIP-Seq(SRA012198)/Homer
# 		6 of 428 (1e-28) Tgif1(Homeobox)/mES-Tgif1-ChIP-Seq(GSE55404)/Homer
# 		7 of 428 (1e-28) HLF(bZIP)/HSC-HLF.Flag-ChIP-Seq(GSE69817)/Homer
# 		8 of 428 (1e-27) Rfx2(HTH)/LoVo-RFX2-ChIP-Seq(GSE49402)/Homer
# 		9 of 428 (1e-27) Mef2b(MADS)/HEK293-Mef2b.V5-ChIP-Seq(GSE67450)/Homer
# 		10 of 428 (1e-25) Meis1(Homeobox)/MastCells-Meis1-ChIP-Seq(GSE48085)/Homer
# 		11 of 428 (1e-25) X-box(HTH)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer
# 		12 of 428 (1e-25) Maz(Zf)/HepG2-Maz-ChIP-Seq(GSE31477)/Homer
# 		13 of 428 (1e-25) Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer
# 		14 of 428 (1e-24) Mef2a(MADS)/HL1-Mef2a.biotin-ChIP-Seq(GSE21529)/Homer
# 		15 of 428 (1e-23) HIC1(Zf)/Treg-ZBTB29-ChIP-Seq(GSE99889)/Homer
# 		16 of 428 (1e-23) Mef2c(MADS)/GM12878-Mef2c-ChIP-Seq(GSE32465)/Homer
# 		17 of 428 (1e-22) Sox9(HMG)/Limb-SOX9-ChIP-Seq(GSE73225)/Homer
# 		18 of 428 (1e-22) Sox15(HMG)/CPA-Sox15-ChIP-Seq(GSE62909)/Homer
# 		19 of 428 (1e-21) Jun-AP1(bZIP)/K562-cJun-ChIP-Seq(GSE31477)/Homer
# 		20 of 428 (1e-21) Fra1(bZIP)/BT549-Fra1-ChIP-Seq(GSE46166)/Homer
# 		21 of 428 (1e-21) NF1(CTF)/LNCAP-NF1-ChIP-Seq(Unpublished)/Homer
# 		22 of 428 (1e-21) Sox2(HMG)/mES-Sox2-ChIP-Seq(GSE11431)/Homer
# 		23 of 428 (1e-19) Tlx?(NR)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer
# 		24 of 428 (1e-19) Fosl2(bZIP)/3T3L1-Fosl2-ChIP-Seq(GSE56872)/Homer
# 		25 of 428 (1e-19) AP-1(bZIP)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
# 		26 of 428 (1e-19) Fra2(bZIP)/Striatum-Fra2-ChIP-Seq(GSE43429)/Homer
# 		27 of 428 (1e-19) Sox3(HMG)/NPC-Sox3-ChIP-Seq(GSE33059)/Homer
# 		28 of 428 (1e-17) Rfx1(HTH)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer
# =		29 of 428 (1e-16) ERG(ETS)/VCaP-ERG-ChIP-Seq(GSE14097)/Homer
# 		30 of 428 (1e-16) BATF(bZIP)/Th17-BATF-ChIP-Seq(GSE39756)/Homer
# 		31 of 428 (1e-16) Zfp281(Zf)/ES-Zfp281-ChIP-Seq(GSE81042)/Homer
# 		32 of 428 (1e-16) WT1(Zf)/Kidney-WT1-ChIP-Seq(GSE90016)/Homer
# 		33 of 428 (1e-16) Sox4(HMG)/proB-Sox4-ChIP-Seq(GSE50066)/Homer
# 		34 of 428 (1e-16) Atf3(bZIP)/GBM-ATF3-ChIP-Seq(GSE33912)/Homer
# 		35 of 428 (1e-15) Sox6(HMG)/Myotubes-Sox6-ChIP-Seq(GSE32627)/Homer
# 		36 of 428 (1e-15) JunB(bZIP)/DendriticCells-Junb-ChIP-Seq(GSE36099)/Homer
# 		37 of 428 (1e-14) Dlx3(Homeobox)/Kerainocytes-Dlx3-ChIP-Seq(GSE89884)/Homer
# 		38 of 428 (1e-14) Sox10(HMG)/SciaticNerve-Sox3-ChIP-Seq(GSE35132)/Homer
# 		39 of 428 (1e-13) Foxo1(Forkhead)/RAW-Foxo1-ChIP-Seq(Fan_et_al.)/Homer
# 		40 of 428 (1e-13) Tbx5(T-box)/HL1-Tbx5.biotin-ChIP-Seq(GSE21529)/Homer
# 		41 of 428 (1e-13) Bach2(bZIP)/OCILy7-Bach2-ChIP-Seq(GSE44420)/Homer
# 		42 of 428 (1e-13) Unknown-ESC-element(?)/mES-Nanog-ChIP-Seq(GSE11724)/Homer
# 		43 of 428 (1e-12) Elf4(ETS)/BMDM-Elf4-ChIP-Seq(GSE88699)/Homer
# 		44 of 428 (1e-12) KLF14(Zf)/HEK293-KLF14.GFP-ChIP-Seq(GSE58341)/Homer
# 		45 of 428 (1e-12) SCL(bHLH)/HPC7-Scl-ChIP-Seq(GSE13511)/Homer
# 		46 of 428 (1e-10) Zic3(Zf)/mES-Zic3-ChIP-Seq(GSE37889)/Homer
# 		47 of 428 (1e-10) Rbpj1(?)/Panc1-Rbpj1-ChIP-Seq(GSE47459)/Homer
# 		48 of 428 (1e-10) Lhx1(Homeobox)/EmbryoCarcinoma-Lhx1-ChIP-Seq(GSE70957)/Homer
# 		49 of 428 (1e-10) LXH9(Homeobox)/Hct116-LXH9.V5-ChIP-Seq(GSE116822)/Homer
# 		50 of 428 (1e-9) Prop1(Homeobox)/GHFT1-PROP1.biotin-ChIP-Seq(GSE77302)/Homer
# 		51 of 428 (1e-9) Nkx6.1(Homeobox)/Islet-Nkx6.1-ChIP-Seq(GSE40975)/Homer
# 		52 of 428 (1e-9) Hoxc9(Homeobox)/Ainv15-Hoxc9-ChIP-Seq(GSE21812)/Homer
# 		53 of 428 (1e-9) OCT:OCT(POU,Homeobox,IR1)/NPC-Brn2-ChIP-Seq(GSE35496)/Homer
# 		54 of 428 (1e-9) Etv2(ETS)/ES-ER71-ChIP-Seq(GSE59402)/Homer
# 		55 of 428 (1e-9) Lhx3(Homeobox)/Neuron-Lhx3-ChIP-Seq(GSE31456)/Homer
# 		56 of 428 (1e-9) MafA(bZIP)/Islet-MafA-ChIP-Seq(GSE30298)/Homer
# 		57 of 428 (1e-9) Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer
# 		58 of 428 (1e-9) AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer
# 		59 of 428 (1e-9) Tcf12(bHLH)/GM12878-Tcf12-ChIP-Seq(GSE32465)/Homer
# =		60 of 428 (1e-9) Ascl1(bHLH)/NeuralTubes-Ascl1-ChIP-Seq(GSE55840)/Homer
# 		61 of 428 (1e-9) FoxD3(forkhead)/ZebrafishEmbryo-Foxd3.biotin-ChIP-seq(GSE106676)/Homer
# 		62 of 428 (1e-8) Sp5(Zf)/mES-Sp5.Flag-ChIP-Seq(GSE72989)/Homer
# 		63 of 428 (1e-8) EBF1(EBF)/Near-E2A-ChIP-Seq(GSE21512)/Homer
# 		64 of 428 (1e-8) NFAT(RHD)/Jurkat-NFATC1-ChIP-Seq(Jolma_et_al.)/Homer
# 		65 of 428 (1e-7) MyoG(bHLH)/C2C12-MyoG-ChIP-Seq(GSE36024)/Homer
# 		66 of 428 (1e-7) Zic(Zf)/Cerebellum-ZIC1.2-ChIP-Seq(GSE60731)/Homer
# 		67 of 428 (1e-7) EWS:ERG-fusion(ETS)/CADO_ES1-EWS:ERG-ChIP-Seq(SRA014231)/Homer
# 		68 of 428 (1e-7) CEBP(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512)/Homer
# 		69 of 428 (1e-7) PU.1(ETS)/ThioMac-PU.1-ChIP-Seq(GSE21512)/Homer
# 		70 of 428 (1e-7) ETV1(ETS)/GIST48-ETV1-ChIP-Seq(GSE22441)/Homer
# 		71 of 428 (1e-7) Pbx3(Homeobox)/GM12878-PBX3-ChIP-Seq(GSE32465)/Homer
# 		72 of 428 (1e-7) NF-E2(bZIP)/K562-NFE2-ChIP-Seq(GSE31477)/Homer
# 		73 of 428 (1e-7) Brn1(POU,Homeobox)/NPC-Brn1-ChIP-Seq(GSE35496)/Homer
# 		74 of 428 (1e-7) TFE3(bHLH)/MEF-TFE3-ChIP-Seq(GSE75757)/Homer
# 		75 of 428 (1e-7) Oct6(POU,Homeobox)/NPC-Pou3f1-ChIP-Seq(GSE35496)/Homer
# 		76 of 428 (1e-6) Egr2(Zf)/Thymocytes-Egr2-ChIP-Seq(GSE34254)/Homer
# 		77 of 428 (1e-6) PBX1(Homeobox)/MCF7-PBX1-ChIP-Seq(GSE28007)/Homer
# 		78 of 428 (1e-6) EHF(ETS)/LoVo-EHF-ChIP-Seq(GSE49402)/Homer
# 		79 of 428 (1e-6) Smad4(MAD)/ESC-SMAD4-ChIP-Seq(GSE29422)/Homer
# 		80 of 428 (1e-6) Nanog(Homeobox)/mES-Nanog-ChIP-Seq(GSE11724)/Homer
# 		81 of 428 (1e-6) GABPA(ETS)/Jurkat-GABPa-ChIP-Seq(GSE17954)/Homer
# 		82 of 428 (1e-6) Bach1(bZIP)/K562-Bach1-ChIP-Seq(GSE31477)/Homer
# 		83 of 428 (1e-6) Isl1(Homeobox)/Neuron-Isl1-ChIP-Seq(GSE31456)/Homer
# 		84 of 428 (1e-6) EWS:FLI1-fusion(ETS)/SK_N_MC-EWS:FLI1-ChIP-Seq(SRA014231)/Homer
# 		85 of 428 (1e-6) Nrf2(bZIP)/Lymphoblast-Nrf2-ChIP-Seq(GSE37589)/Homer
# 		86 of 428 (1e-6) Tcf21(bHLH)/ArterySmoothMuscle-Tcf21-ChIP-Seq(GSE61369)/Homer
# 		87 of 428 (1e-6) Phox2a(Homeobox)/Neuron-Phox2a-ChIP-Seq(GSE31456)/Homer
# 		88 of 428 (1e-6) ELF3(ETS)/PDAC-ELF3-ChIP-Seq(GSE64557)/Homer
# 		89 of 428 (1e-6) ELF5(ETS)/T47D-ELF5-ChIP-Seq(GSE30407)/Homer
# 		90 of 428 (1e-6) AP-2gamma(AP2)/MCF7-TFAP2C-ChIP-Seq(GSE21234)/Homer
# 		91 of 428 (1e-6) STAT6(Stat)/Macrophage-Stat6-ChIP-Seq(GSE38377)/Homer
# 		92 of 428 (1e-6) OCT:OCT-short(POU,Homeobox)/NPC-OCT6-ChIP-Seq(GSE43916)/Homer
# 		93 of 428 (1e-5) FOXP1(Forkhead)/H9-FOXP1-ChIP-Seq(GSE31006)/Homer
# 		94 of 428 (1e-5) Oct11(POU,Homeobox)/NCIH1048-POU2F3-ChIP-seq(GSE115123)/Homer
# 		95 of 428 (1e-5) Ets1-distal(ETS)/CD4+-PolII-ChIP-Seq(Barski_et_al.)/Homer
# 		96 of 428 (1e-5) Lhx2(Homeobox)/HFSC-Lhx2-ChIP-Seq(GSE48068)/Homer
# 		97 of 428 (1e-5) GLIS3(Zf)/Thyroid-Glis3.GFP-ChIP-Seq(GSE103297)/Homer
# 		98 of 428 (1e-5) AP-2alpha(AP2)/Hela-AP2alpha-ChIP-Seq(GSE31477)/Homer
# 		99 of 428 (1e-5) BMYB(HTH)/Hela-BMYB-ChIP-Seq(GSE27030)/Homer
# 		100 of 428 (1e-5) Usf2(bHLH)/C2C12-Usf2-ChIP-Seq(GSE36030)/Homer
# 		101 of 428 (1e-5) CEBP:AP1(bZIP)/ThioMac-CEBPb-ChIP-Seq(GSE21512)/Homer
# 		102 of 428 (1e-5) Tbr1(T-box)/Cortex-Tbr1-ChIP-Seq(GSE71384)/Homer
# 		103 of 428 (1e-5) FOXK2(Forkhead)/U2OS-FOXK2-ChIP-Seq(E-MTAB-2204)/Homer
# 		104 of 428 (1e-4) Oct4(POU,Homeobox)/mES-Oct4-ChIP-Seq(GSE11431)/Homer
# 		105 of 428 (1e-4) RORgt(NR)/EL4-RORgt.Flag-ChIP-Seq(GSE56019)/Homer
# 		106 of 428 (1e-4) RORgt(NR)/EL4-RORgt.Flag-ChIP-Seq(GSE56019)/Homer
# 		107 of 428 (1e-4) ETV4(ETS)/HepG2-ETV4-ChIP-Seq(ENCODE)/Homer
# 		108 of 428 (1e-4) ETS:E-box(ETS,bHLH)/HPC7-Scl-ChIP-Seq(GSE22178)/Homer
# 		109 of 428 (1e-4) Smad2(MAD)/ES-SMAD2-ChIP-Seq(GSE29422)/Homer
# 		110 of 428 (1e-4) EBF(EBF)/proBcell-EBF-ChIP-Seq(GSE21978)/Homer
# 		111 of 428 (1e-4) HRE(HSF)/Striatum-HSF1-ChIP-Seq(GSE38000)/Homer
# 		112 of 428 (1e-4) STAT6(Stat)/CD4-Stat6-ChIP-Seq(GSE22104)/Homer
# 		113 of 428 (1e-4) ZBTB18(Zf)/HEK293-ZBTB18.GFP-ChIP-Seq(GSE58341)/Homer
# 		114 of 428 (1e-4) USF1(bHLH)/GM12878-Usf1-ChIP-Seq(GSE32465)/Homer
# 		115 of 428 (1e-4) TEAD(TEA)/Fibroblast-PU.1-ChIP-Seq(Unpublished)/Homer
# 		116 of 428 (1e-4) MYB(HTH)/ERMYB-Myb-ChIPSeq(GSE22095)/Homer
# 		117 of 428 (1e-4) Ap4(bHLH)/AML-Tfap4-ChIP-Seq(GSE45738)/Homer
# 		118 of 428 (1e-4) ETS1(ETS)/Jurkat-ETS1-ChIP-Seq(GSE17954)/Homer
# 		119 of 428 (1e-4) PBX2(Homeobox)/K562-PBX2-ChIP-Seq(Encode)/Homer
# 		120 of 428 (1e-4) TEAD3(TEA)/HepG2-TEAD3-ChIP-Seq(Encode)/Homer
# 		121 of 428 (1e-4) OCT:OCT(POU,Homeobox)/NPC-Brn1-ChIP-Seq(GSE35496)/Homer
# 		122 of 428 (1e-4) OCT4-SOX2-TCF-NANOG(POU,Homeobox,HMG)/mES-Oct4-ChIP-Seq(GSE11431)/Homer
# 		123 of 428 (1e-4) MafK(bZIP)/C2C12-MafK-ChIP-Seq(GSE36030)/Homer
# 		124 of 428 (1e-4) Eomes(T-box)/H9-Eomes-ChIP-Seq(GSE26097)/Homer
# 		125 of 428 (1e-4) RORg(NR)/Liver-Rorc-ChIP-Seq(GSE101115)/Homer
# 		126 of 428 (1e-4) Pdx1(Homeobox)/Islet-Pdx1-ChIP-Seq(SRA008281)/Homer
# 		127 of 428 (1e-4) Nkx2.2(Homeobox)/NPC-Nkx2.2-ChIP-Seq(GSE61673)/Homer
# 		128 of 428 (1e-4) STAT5(Stat)/mCD4+-Stat5-ChIP-Seq(GSE12346)/Homer
# 		129 of 428 (1e-4) Fox:Ebox(Forkhead,bHLH)/Panc1-Foxa2-ChIP-Seq(GSE47459)/Homer
# 		130 of 428 (1e-4) Sox17(HMG)/Endoderm-Sox17-ChIP-Seq(GSE61475)/Homer
# 		131 of 428 (1e-4) Foxo3(Forkhead)/U2OS-Foxo3-ChIP-Seq(E-MTAB-2701)/Homer
# 		132 of 428 (1e-3) Pknox1(Homeobox)/ES-Prep1-ChIP-Seq(GSE63282)/Homer
# 		133 of 428 (1e-3) Atoh1(bHLH)/Cerebellum-Atoh1-ChIP-Seq(GSE22111)/Homer
# 		134 of 428 (1e-3) PRDM9(Zf)/Testis-DMC1-ChIP-Seq(GSE35498)/Homer
# 		135 of 428 (1e-3) GATA(Zf),IR4/iTreg-Gata3-ChIP-Seq(GSE20898)/Homer
# 		136 of 428 (1e-3) EBF2(EBF)/BrownAdipose-EBF2-ChIP-Seq(GSE97114)/Homer
# 		137 of 428 (1e-3) Hoxb4(Homeobox)/ES-Hoxb4-ChIP-Seq(GSE34014)/Homer
# 		138 of 428 (1e-3) PR(NR)/T47D-PR-ChIP-Seq(GSE31130)/Homer
# 		139 of 428 (1e-3) bHLHE41(bHLH)/proB-Bhlhe41-ChIP-Seq(GSE93764)/Homer
# 		140 of 428 (1e-3) PRDM1(Zf)/Hela-PRDM1-ChIP-Seq(GSE31477)/Homer
# 		141 of 428 (1e-3) Pit1+1bp(Homeobox)/GCrat-Pit1-ChIP-Seq(GSE58009)/Homer
# 		142 of 428 (1e-3) Chop(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 		143 of 428 (1e-3) Tbx20(T-box)/Heart-Tbx20-ChIP-Seq(GSE29636)/Homer
# 		144 of 428 (1e-3) Sp2(Zf)/HEK293-Sp2.eGFP-ChIP-Seq(Encode)/Homer
# 		145 of 428 (1e-3) TATA-Box(TBP)/Promoter/Homer
# 		146 of 428 (1e-3) E2F6(E2F)/Hela-E2F6-ChIP-Seq(GSE31477)/Homer
# 		147 of 428 (1e-3) PU.1-IRF(ETS:IRF)/Bcell-PU.1-ChIP-Seq(GSE21512)/Homer
# 		148 of 428 (1e-3) ZNF317(Zf)/HEK293-ZNF317.GFP-ChIP-Seq(GSE58341)/Homer
# 		149 of 428 (1e-3) Bapx1(Homeobox)/VertebralCol-Bapx1-ChIP-Seq(GSE36672)/Homer
# 		150 of 428 (1e-3) ZNF519(Zf)/HEK293-ZNF519.GFP-ChIP-Seq(GSE58341)/Homer
# 		151 of 428 (1e-3) Myf5(bHLH)/GM-Myf5-ChIP-Seq(GSE24852)/Homer
# 		152 of 428 (1e-3) NFkB-p65-Rel(RHD)/ThioMac-LPS-Expression(GSE23622)/Homer
# 		153 of 428 (1e-3) E-box(bHLH)/Promoter/Homer
# 		154 of 428 (1e-3) STAT4(Stat)/CD4-Stat4-ChIP-Seq(GSE22104)/Homer
# 		155 of 428 (1e-3) MITF(bHLH)/MastCells-MITF-ChIP-Seq(GSE48085)/Homer
# 		156 of 428 (1e-3) CEBP:CEBP(bZIP)/MEF-Chop-ChIP-Seq(GSE35681)/Homer
# 		157 of 428 (1e-3) Rfx6(HTH)/Min6b1-Rfx6.HA-ChIP-Seq(GSE62844)/Homer
# 		158 of 428 (1e-3) MYNN(Zf)/HEK293-MYNN.eGFP-ChIP-Seq(Encode)/Homer
# 		159 of 428 (1e-3) Ascl2(bHLH)/ESC-Ascl2-ChIP-Seq(GSE97712)/Homer
# 		160 of 428 (1e-3) PRDM15(Zf)/ESC-Prdm15-ChIP-Seq(GSE73694)/Homer
# 		161 of 428 (1e-2) DMRT1(DM)/Testis-DMRT1-ChIP-Seq(GSE64892)/Homer
# 		162 of 428 (1e-2) MyoD(bHLH)/Myotube-MyoD-ChIP-Seq(GSE21614)/Homer
# 		163 of 428 (1e-2) FOXK1(Forkhead)/HEK293-FOXK1-ChIP-Seq(GSE51673)/Homer
# 		164 of 428 (1e-2) Zac1(Zf)/Neuro2A-Plagl1-ChIP-Seq(GSE75942)/Homer
# 		165 of 428 (1e-2) CHR(?)/Hela-CellCycle-Expression/Homer
# 		166 of 428 (1e-2) OCT:OCT(POU,Homeobox)/NPC-OCT6-ChIP-Seq(GSE43916)/Homer
# 		167 of 428 (1e-2) ZNF7(Zf)/HepG2-ZNF7.Flag-ChIP-Seq(Encode)/Homer
# 		168 of 428 (1e-2) NF1:FOXA1(CTF,Forkhead)/LNCAP-FOXA1-ChIP-Seq(GSE27824)/Homer
# 		169 of 428 (1e-2) NeuroG2(bHLH)/Fibroblast-NeuroG2-ChIP-Seq(GSE75910)/Homer
# 		170 of 428 (1e-2) MafF(bZIP)/HepG2-MafF-ChIP-Seq(GSE31477)/Homer
# 		171 of 428 (1e-2) ZNF711(Zf)/SHSY5Y-ZNF711-ChIP-Seq(GSE20673)/Homer
# 		172 of 428 (1e-2) Smad3(MAD)/NPC-Smad3-ChIP-Seq(GSE36673)/Homer
# 		173 of 428 (1e-2) bHLHE40(bHLH)/HepG2-BHLHE40-ChIP-Seq(GSE31477)/Homer
# 		174 of 428 (1e-2) Atf1(bZIP)/K562-ATF1-ChIP-Seq(GSE31477)/Homer
# 		175 of 428 (1e-2) Tbx6(T-box)/ESC-Tbx6-ChIP-Seq(GSE93524)/Homer
# 		176 of 428 (1e-2) LEF1(HMG)/H1-LEF1-ChIP-Seq(GSE64758)/Homer
# 		177 of 428 (1e-2) AMYB(HTH)/Testes-AMYB-ChIP-Seq(GSE44588)/Homer
# 		178 of 428 (1e-2) Oct2(POU,Homeobox)/Bcell-Oct2-ChIP-Seq(GSE21512)/Homer
# 		179 of 428 (1e-2) Brn2(POU,Homeobox)/NPC-Brn2-ChIP-Seq(GSE35496)/Homer
# 		180 of 428 (1e-2) JunD(bZIP)/K562-JunD-ChIP-Seq/Homer
# 		181 of 428 (1e-2) Zfp809(Zf)/ES-Zfp809-ChIP-Seq(GSE70799)/Homer
# ...
# 		15 of 35 (1e-56) similar to DBP/MA0639.1/Jaspar(0.924)
# 		16 of 35 (1e-54) similar to Zic(Zf)/Cerebellum-ZIC1.2-ChIP-Seq(GSE60731)/Homer(0.739)
# 		17 of 35 (1e-53) similar to PB0176.1_Sox5_2/Jaspar(0.821)
# 		18 of 35 (1e-51) similar to RBPJ/MA1116.1/Jaspar(0.752)
# 		19 of 35 (1e-42) similar to BMYB(HTH)/Hela-BMYB-ChIP-Seq(GSE27030)/Homer(0.826)
# 		20 of 35 (1e-33) similar to IRF4(IRF)/GM12878-IRF4-ChIP-Seq(GSE32465)/Homer(0.760)
# 		21 of 35 (1e-31) similar to PB0006.1_Bcl6b_1/Jaspar(0.664)
# 		22 of 35 (1e-30) similar to Rfx1(HTH)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer(0.885)
# 		23 of 35 (1e-25) similar to JDP2/MA0655.1/Jaspar(0.955)
# 		24 of 35 (1e-24) similar to ETS:E-box(ETS,bHLH)/HPC7-Scl-ChIP-Seq(GSE22178)/Homer(0.608)
# 		25 of 35 (1e-21) similar to Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer(0.691)
# 		26 of 35 (1e-15) similar to Sox2/MA0143.3/Jaspar(0.774)
# 		27 of 35 (1e-14) similar to Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer(0.673)
# 		28 of 35 (1e-14) similar to Atf4(bZIP)/MEF-Atf4-ChIP-Seq(GSE35681)/Homer(0.725)
# 		29 of 35 (1e-13) similar to Nkx2.1(Homeobox)/LungAC-Nkx2.1-ChIP-Seq(GSE43252)/Homer(0.729)
# 		30 of 35 (1e-13) similar to DMRT3/MA0610.1/Jaspar(0.560)
# 		31 of 35 (1e-13) similar to Smad4(MAD)/ESC-SMAD4-ChIP-Seq(GSE29422)/Homer(0.679)
# 		32 of 35 (1e-10) similar to PB0130.1_Gm397_2/Jaspar(0.798)
# 		33 of 35 (1e-7) similar to Brn1(POU,Homeobox)/NPC-Brn1-ChIP-Seq(GSE35496)/Homer(0.595)
# 		34 of 35 (1e-5) similar to PB0163.1_Six6_2/Jaspar(0.757)
# 		35 of 35 (1e-3) similar to RUNX2(Runt)/PCa-RUNX2-ChIP-Seq(GSE33889)/Homer(0.682)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
# 	125339 finished
# 		Round 2: -94.07 TGTCTGACAGAC T:1854.0(4.03%),B:1322.5(2.90%),P:1e-40
# 		=Final=: -76.28 TTGACAGGCACG T:2550.0(5.07%),B:1995.7(3.97%),P:1e-33
# 		Performing exhaustive masking of motif...
# 		=Final=: -68.08 TGTCTGACAGAC T:1849.0(4.10%),B:1406.7(3.13%),P:1e-29
# 		Performing exhaustive masking of motif...
# 		Round 3: -68.51 GCTGTGAGAATC T:2364.0(4.11%),B:1838.4(3.23%),P:1e-29
# 		Reprioritizing potential motifs...
# 		Reprioritizing potential motifs...
# 		=Final=: -69.00 GCTGTGAGAATC T:27480.0(48.83%),B:26080.8(46.42%),P:1e-29
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: GACAGACATGAG... (-58.858)
# 		Round 1: -107.44 GACAGACATGAG T:40.0(0.08%),B:2.9(0.00%),P:1e-46
# 		Round 2: -107.44 GACAGACATGAG T:40.0(0.08%),B:2.9(0.00%),P:1e-46
# 	18 of 25 Initial Sequence: AGAGGGGCAGAG... (-59.425)
# 		Round 1: -84.68 AGAGGGGCAGAG T:166.0(0.37%),B:51.3(0.11%),P:1e-36
# 	24 of 25 Initial Sequence: TCTGTCTATCTA... (-54.764)
# 		=Final=: -55.75 GACAGACATGAG T:30.0(0.06%),B:2.9(0.01%),P:1e-24
# 		Performing exhaustive masking of motif...
# 		Round 2: -84.68 AGAGGGGCAGAG T:166.0(0.37%),B:51.3(0.11%),P:1e-36
# 		Round 1: -65.04 TCTGTCTATCTA T:1466.0(2.57%),B:1074.4(1.90%),P:1e-28
# 		Round 2: -65.74 TCTGTCTATCYA T:1531.0(2.68%),B:1127.9(1.99%),P:1e-28
# 		=Final=: -13.65 AGAGGGGCAGAG T:90.0(0.20%),B:52.1(0.12%),P:1e-5
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 		Round 3: -71.70 TCTRTCTATCYA T:1678.0(2.94%),B:1235.7(2.18%),P:1e-31
# 		Round 4: -71.70 TCTRTCTATCYA T:1678.0(2.94%),B:1235.7(2.18%),P:1e-31
# 		Reprioritizing potential motifs...
# 		=Final=: -26.86 TCTRTCTATCYA T:271.0(0.48%),B:172.7(0.31%),P:1e-11
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	100674 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=============================================	19 of 25 Initial Sequence: CCTGCATCCCCT... (-58.932)
# ================		Round 1: -69.48 CCTGCATCCCCT T:60.0(0.13%),B:9.6(0.02%),P:1e-30
# ====	25 of 25 Initial Sequence: GGGGAGCCTGTG... (-52.467)
# 		Round 2: -69.48 CCTGCATCCCCT T:60.0(0.13%),B:9.6(0.02%),P:1e-30
# 		Round 1: -68.74 GGGGAGCCTGTG T:29.0(0.05%),B:2.8(0.00%),P:1e-29
# =========		Round 2: -68.74 GGGGAGCCTGTG T:29.0(0.05%),B:2.8(0.00%),P:1e-29
# =======		=Final=: -22.54 CCTGCATCCCCT T:34.0(0.08%),B:9.6(0.02%),P:1e-9
# 		Performing exhaustive masking of motif...
# 		=Final=: -32.70 GGGGAGCCTGTG T:21.0(0.04%),B:2.8(0.01%),P:1e-14
# 		Performing exhaustive masking of motif...
#
# 	Output in file: Motifs-peaks-FoldEnrich-6.-distal.txt/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs...		Reprioritizing potential motifs...
#  75 reduced to 30 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	112554 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	================================	20 of 25 Initial Sequence: AAAAGCACAGTG... (-58.666)
# 	Formatting HTML page...
# 		1 of 30 (1e-99) similar to POL010.1_DCE_S_III/Jaspar(0.700)
# 		2 of 30 (1e-97) similar to Lhx2(Homeobox)/HFSC-Lhx2-ChIP-Seq(GSE48068)/Homer(0.932)
# 		3 of 30 (1e-92) similar to PB0091.1_Zbtb3_1/Jaspar(0.719)
# 		4 of 30 (1e-88) similar to MEIS2/MA0774.1/Jaspar(0.814)
# 		5 of 30 (1e-74) similar to MEF2A/MA0052.3/Jaspar(0.946)
# 		6 of 30 (1e-71) similar to PB0205.1_Zic1_2/Jaspar(0.778)
# 		7 of 30 (1e-70) similar to Fox:Ebox(Forkhead,bHLH)/Panc1-Foxa2-ChIP-Seq(GSE47459)/Homer(0.762)
# 		8 of 30 (1e-67) similar to MAFG::NFE2L1/MA0089.1/Jaspar(0.734)
# 		9 of 30 (1e-61) similar to PB0170.1_Sox17_2/Jaspar(0.664)
# 		10 of 30 (1e-59) similar to PRDM1(Zf)/Hela-PRDM1-ChIP-Seq(GSE31477)/Homer(0.684)
# 		11 of 30 (1e-56) similar to ZNF740/MA0753.1/Jaspar(0.873)
# 		12 of 30 (1e-56) similar to NRL/MA0842.1/Jaspar(0.664)
# 		13 of 30 (1e-52) similar to POL013.1_MED-1/Jaspar(0.671)
# 		14 of 30 (1e-51) similar to PB0187.1_Tcf7_2/Jaspar(0.727)
# 		15 of 30 (1e-51) similar to DBP/MA0639.1/Jaspar(0.940)
# 		16 of 30 (1e-49) similar to Stat5a::Stat5b/MA0519.1/Jaspar(0.662)
# 		17 of 30 (1e-48) similar to AR-halfsite(NR)/LNCaP-AR-ChIP-Seq(GSE27824)/Homer(0.635)
# 		18 of 30 (1e-45) similar to CEBPD/MA0836.1/Jaspar(0.606)
# 		19 of 30 (1e-38) similar to PB0115.1_Ehf_2/Jaspar(0.764)
# 		20 of 30 (1e-32) similar to FOXO3/MA0157.2/Jaspar(0.709)
# 		21 of 30 (1e-30) similar to PB0168.1_Sox14_2/Jaspar(0.726)
# 		22 of 30 (1e-26) similar to Sox2/MA0143.3/Jaspar(0.928)
# 		23 of 30 (1e-23) similar to Smad4(MAD)/ESC-SMAD4-ChIP-Seq(GSE29422)/Homer(0.632)
# 		24 of 30 (1e-21) similar to Sox9(HMG)/Limb-SOX9-ChIP-Seq(GSE73225)/Homer(0.662)
# 		25 of 30 (1e-21) similar to TEF/MA0843.1/Jaspar(0.575)
# 		26 of 30 (1e-21) similar to Zac1(Zf)/Neuro2A-Plagl1-ChIP-Seq(GSE75942)/Homer(0.622)
# 		27 of 30 (1e-17) similar to KLF4/MA0039.3/Jaspar(0.752)
# 		28 of 30 (1e-14) similar to Tbox:Smad(T-box,MAD)/ESCd5-Smad2_3-ChIP-Seq(GSE29422)/Homer(0.640)
# 		29 of 30 (1e-7) similar to PRDM1(Zf)/Hela-PRDM1-ChIP-Seq(GSE31477)/Homer(0.589)
# 		30 of 30 (1e-6) similar to PB0080.1_Tbp_1/Jaspar(0.802)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
# 	125335 finished
# ==========		Round 1: -67.45 AAAAGCACAGTG T:2753.0(5.92%),B:2182.0(4.75%),P:1e-29
# =======================		Round 2: -71.62 AAAAGCACAGTG T:22296.0(39.01%),B:20270.5(36.35%),P:1e-31
# 		Round 3: -72.05 AAAAGCACAGTG T:16447.0(30.56%),B:14777.1(28.06%),P:1e-31
# ================		Round 4: -79.61 AAAAGCACAGTG T:18194.0(33.20%),B:16328.8(30.51%),P:1e-34
# 		Round 5: -79.61 AAAAGCACAGTG T:18194.0(33.20%),B:16328.8(30.51%),P:1e-34
#
# 	Output in file: Motifs-peaks-FoldEnrich-5.-distal.txt/homerMotifs.motifs12
#
# 		=Final=: -103.52 AAAAGCACAGTG T:14785.0(32.79%),B:13374.8(29.72%),P:1e-44
# 		Performing exhaustive masking of motif...
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 75 reduced to 33 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 		Reprioritizing potential motifs...
# 	21 of 25 Initial Sequence: TCTGTTTAAACA... (-56.591)
# 	Formatting HTML page...
# 		1 of 33 (1e-122) similar to PB0091.1_Zbtb3_1/Jaspar(0.709)
# 		2 of 33 (1e-103) similar to Tlx?(NR)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer(0.767)
# 		3 of 33 (1e-96) similar to Nr2e3/MA0164.1/Jaspar(0.710)
# 		4 of 33 (1e-95) similar to Lhx2(Homeobox)/HFSC-Lhx2-ChIP-Seq(GSE48068)/Homer(0.932)
# 		5 of 33 (1e-85) similar to POL009.1_DCE_S_II/Jaspar(0.779)
# 		6 of 33 (1e-83) similar to Oct4(POU,Homeobox)/mES-Oct4-ChIP-Seq(GSE11431)/Homer(0.692)
# 		7 of 33 (1e-79) similar to Mef2d(MADS)/Retina-Mef2d-ChIP-Seq(GSE61391)/Homer(0.931)
# 		8 of 33 (1e-78) similar to CHR(?)/Hela-CellCycle-Expression/Homer(0.718)
# 		9 of 33 (1e-70) similar to MZF1/MA0056.1/Jaspar(0.813)
# 		10 of 33 (1e-67) similar to RBPJ/MA1116.1/Jaspar(0.725)
# 		11 of 33 (1e-58) similar to Nur77(NR)/K562-NR4A1-ChIP-Seq(GSE31363)/Homer(0.761)
# 		12 of 33 (1e-55) similar to Foxo1(Forkhead)/RAW-Foxo1-ChIP-Seq(Fan_et_al.)/Homer(0.748)
# 		13 of 33 (1e-52) similar to PB0091.1_Zbtb3_1/Jaspar(0.829)
# 		14 of 33 (1e-51) similar to FOS::JUN/MA0099.3/Jaspar(0.921)
# 		15 of 33 (1e-49) similar to MF0010.1_Homeobox_class/Jaspar(0.727)
# 		16 of 33 (1e-49) similar to HIC1(Zf)/Treg-ZBTB29-ChIP-Seq(GSE99889)/Homer(0.811)
# 		17 of 33 (1e-48) similar to TEF/MA0843.1/Jaspar(0.743)
# 		18 of 33 (1e-48) similar to Tgif1(Homeobox)/mES-Tgif1-ChIP-Seq(GSE55404)/Homer(0.704)
# 		19 of 33 (1e-48) similar to Znf263(Zf)/K562-Znf263-ChIP-Seq(GSE31477)/Homer(0.725)
# 		20 of 33 (1e-43) similar to PB0186.1_Tcf3_2/Jaspar(0.711)
# 		21 of 33 (1e-42) similar to PB0097.1_Zfp281_1/Jaspar(0.911)
# 		22 of 33 (1e-37) similar to Rfx1/MA0509.1/Jaspar(0.806)
# 		23 of 33 (1e-36) similar to Smad2(MAD)/ES-SMAD2-ChIP-Seq(GSE29422)/Homer(0.627)
# 		24 of 33 (1e-35) similar to ZNF768(Zf)/Rajj-ZNF768-ChIP-Seq(GSE111879)/Homer(0.716)
# 		25 of 33 (1e-34) similar to NFATC2/MA0152.1/Jaspar(0.657)
# 		26 of 33 (1e-24) similar to PB0045.1_Myb_1/Jaspar(0.690)
# 		27 of 33 (1e-24) similar to POU2F2/MA0507.1/Jaspar(0.813)
# 		28 of 33 (1e-22) similar to GLI3(Zf)/Limb-GLI3-ChIP-Chip(GSE11077)/Homer(0.680)
# 		29 of 33 (1e-16) similar to DMRT3/MA0610.1/Jaspar(0.634)
# 		30 of 33 (1e-11) similar to Egr2(Zf)/Thymocytes-Egr2-ChIP-Seq(GSE34254)/Homer(0.649)
# 		31 of 33 (1e-10) similar to PH0048.1_Hoxa13/Jaspar(0.692)
# 		32 of 33 (1e-8) similar to PB0080.1_Tbp_1/Jaspar(0.815)
# 		33 of 33 (1e-7) similar to PB0130.1_Gm397_2/Jaspar(0.692)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
# 	125334 finished
# 		Round 1: -74.45 NCTGTTTAAACH T:13943.0(26.60%),B:12412.6(24.17%),P:1e-32
# 		Round 2: -74.45 NCTGTTTAAACH T:13943.0(26.60%),B:12412.6(24.17%),P:1e-32
# 		=Final=: -59.67 NCTGTTTAAACH T:10299.0(22.84%),B:9355.3(20.79%),P:1e-25
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	22 of 25 Initial Sequence: TAATTATTCATG... (-53.159)
# 		Round 1: -70.22 TAATTATTCATG T:1159.0(2.54%),B:803.1(1.77%),P:1e-30
# 		Round 2: -70.49 TAATTATTCATG T:1204.0(2.63%),B:839.1(1.85%),P:1e-30
# 		Round 3: -72.21 TAATTATTCATG T:1047.0(2.30%),B:707.0(1.56%),P:1e-31
# 		Round 4: -72.21 TAATTATTCATG T:1047.0(2.30%),B:707.0(1.56%),P:1e-31
# 		=Final=: -77.51 TAATTATTCATG T:1020.0(2.26%),B:680.2(1.51%),P:1e-33
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	23 of 25 Initial Sequence: AAGCTCGCACAG... (-52.913)
# 		Round 1: -61.31 AAGCTCGCACAG T:2721.0(5.86%),B:2178.8(4.74%),P:1e-26
# 		Round 2: -76.58 AAGCTCGCACAG T:1759.0(3.83%),B:1289.5(2.83%),P:1e-33
# 		Round 3: -76.58 AAGCTCGCACAG T:1759.0(3.83%),B:1289.5(2.83%),P:1e-33
# 		=Final=: -75.60 AAGCTCGCACAG T:1715.0(3.80%),B:1268.8(2.82%),P:1e-32
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	24 of 25 Initial Sequence: TGGATAGATAGA... (-52.460)
# 		Round 1: -55.63 TGGATAGATAGA T:25.0(0.06%),B:3.0(0.00%),P:1e-24
# 		Round 2: -68.73 CGGATAGATAGA T:29.0(0.06%),B:3.0(0.00%),P:1e-29
# 		Round 3: -82.38 CGGATAGATAGA T:33.0(0.07%),B:3.0(0.00%),P:1e-35
# 		Round 4: -82.38 CGGATAGATAGA T:33.0(0.07%),B:3.0(0.00%),P:1e-35
# 		=Final=: -47.73 CGGATAGATAGA T:27.0(0.06%),B:3.0(0.01%),P:1e-20
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
# 	25 of 25 Initial Sequence: AGAGCTCAGCCA... (-52.460)
# 		Round 1: -68.73 AGAGCTCAGCCA T:29.0(0.06%),B:2.2(0.00%),P:1e-29
# 		Round 2: -72.09 CGAGCTCAGCCA T:30.0(0.07%),B:2.2(0.00%),P:1e-31
# 		Round 3: -72.09 CGAGCTCAGCCA T:30.0(0.07%),B:2.2(0.00%),P:1e-31
# 		=Final=: -55.75 CGAGCTCAGCCA T:30.0(0.07%),B:2.2(0.00%),P:1e-24
# 		Performing exhaustive masking of motif...
# 		Reprioritizing potential motifs...
#
# 	Finalizing Enrichment Statistics (new in v3.4)
# 	Reading input files...
# 	90178 total sequences read
# 	Cache length = 11180
# 	Using binomial scoring
# 	Checking enrichment of 25 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Output in file: Motifs-peaks-FoldEnrich-7.-distal.txt/homerMotifs.motifs12
#
# 	(Motifs in homer2 format)
# 	Determining similar motifs... 75 reduced to 36 motifs
# 	Outputing HTML and sequence logos for motif comparison...
# 	Checking de novo motifs against known motifs...
# 	Formatting HTML page...
# 		1 of 36 (1e-86) similar to SOX10/MA0442.2/Jaspar(0.726)
# 		2 of 36 (1e-82) similar to HIC1(Zf)/Treg-ZBTB29-ChIP-Seq(GSE99889)/Homer(0.872)
# 		3 of 36 (1e-79) similar to BMYB(HTH)/Hela-BMYB-ChIP-Seq(GSE27030)/Homer(0.683)
# 		4 of 36 (1e-75) similar to EMX2/MA0886.1/Jaspar(0.877)
# 		5 of 36 (1e-74) similar to Znf263(Zf)/K562-Znf263-ChIP-Seq(GSE31477)/Homer(0.714)
# 		6 of 36 (1e-73) similar to POL008.1_DCE_S_I/Jaspar(0.691)
# 		7 of 36 (1e-67) similar to Mef2d(MADS)/Retina-Mef2d-ChIP-Seq(GSE61391)/Homer(0.963)
# 		8 of 36 (1e-66) similar to ISL2/MA0914.1/Jaspar(0.733)
# 		9 of 36 (1e-62) similar to STAT6(Stat)/Macrophage-Stat6-ChIP-Seq(GSE38377)/Homer(0.648)
# 		10 of 36 (1e-60) similar to Tcf7(HMG)/GM12878-TCF7-ChIP-Seq(Encode)/Homer(0.654)
# 		11 of 36 (1e-59) similar to PB0187.1_Tcf7_2/Jaspar(0.737)
# 		12 of 36 (1e-57) similar to PB0145.1_Mafb_2/Jaspar(0.794)
# 		13 of 36 (1e-56) similar to Zic3(Zf)/mES-Zic3-ChIP-Seq(GSE37889)/Homer(0.733)
# 		14 of 36 (1e-56) similar to Egr1(Zf)/K562-Egr1-ChIP-Seq(GSE32465)/Homer(0.794)
# 		15 of 36 (1e-54) similar to RUNX-AML(Runt)/CD4+-PolII-ChIP-Seq(Barski_et_al.)/Homer(0.671)
# 		16 of 36 (1e-52) similar to PB0097.1_Zfp281_1/Jaspar(0.867)
# 		17 of 36 (1e-49) similar to HOXC13/MA0907.1/Jaspar(0.816)
# 		18 of 36 (1e-46) similar to NFE2/MA0841.1/Jaspar(0.849)
# 		19 of 36 (1e-43) similar to Zic(Zf)/Cerebellum-ZIC1.2-ChIP-Seq(GSE60731)/Homer(0.750)
# 		20 of 36 (1e-41) similar to Rfx1(HTH)/NPC-H3K4me1-ChIP-Seq(GSE16256)/Homer(0.936)
# 		21 of 36 (1e-40) similar to NFIL3/MA0025.1/Jaspar(0.910)
# 		22 of 36 (1e-40) similar to PH0148.1_Pou3f3/Jaspar(0.710)
# 		23 of 36 (1e-37) similar to PB0165.1_Sox11_2/Jaspar(0.773)
# 		24 of 36 (1e-33) similar to mix-a/MA0621.1/Jaspar(0.567)
# 		25 of 36 (1e-28) similar to PB0109.1_Bbx_2/Jaspar(0.770)
# 		26 of 36 (1e-23) similar to CHR(?)/Hela-CellCycle-Expression/Homer(0.703)
# 		27 of 36 (1e-23) similar to PB0199.1_Zfp161_2/Jaspar(0.655)
# 		28 of 36 (1e-20) similar to PB0115.1_Ehf_2/Jaspar(0.625)
# 		29 of 36 (1e-20) similar to PB0194.1_Zbtb12_2/Jaspar(0.558)
# 		30 of 36 (1e-16) similar to Smad3(MAD)/NPC-Smad3-ChIP-Seq(GSE36673)/Homer(0.575)
# 		31 of 36 (1e-15) similar to Tcfl5/MA0632.1/Jaspar(0.663)
# 		32 of 36 (1e-8) similar to PB0126.1_Gata5_2/Jaspar(0.604)
# 		33 of 36 (1e-8) similar to PB0130.1_Gm397_2/Jaspar(0.692)
# 		34 of 36 (1e-7) similar to PB0080.1_Tbp_1/Jaspar(0.799)
# 		35 of 36 (1e-6) similar to ZNF165(Zf)/WHIM12-ZNF165-ChIP-Seq(GSE65937)/Homer(0.753)
# 		36 of 36 (1e-4) similar to PB0202.1_Zfp410_2/Jaspar(0.618)
# 	Job finished - if results look good, please send beer to ..
#
# 	Cleaning up tmp files...
#
# 	125336 finished
# 	ALL FINISHED!!!
# CPU times: user 881 ms, sys: 337 ms, total: 1.22 s
# Wall time: 1h 1min 23s
